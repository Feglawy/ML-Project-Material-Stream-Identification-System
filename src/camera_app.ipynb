# %%
import joblib

model_path = "models/model.pkl"
scaler_path = "models/scaler.pk1"

model = joblib.load(model_path)
scaler = joblib.load(scaler_path)

# %%
import cv2 as cv

class_name = {
    "glass": 0,
    "paper": 1,
    "cardboard": 2,
    "plastic": 3,
    "metal": 4,
    "trash": 5
}

cap = cv.VideoCapture(0)  # 0 = default camera

if not cap.isOpened():
    print("Cannot open camera")
    exit()

while True:
    ret, frame = cap.read()
    if not ret:
        print("Can't receive frame (stream end?)")
        break

    features = feature_extract(frame)
    features = scaler.transform(features)
    
    class_label = model.predict(features)
    probabilty = model.predict_proba(features)

    if probabilty[class_label] > THRESHOLD:
        print(class_label)
    else: 
        print("UNKNOWN")


    if cv.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv.destroyAllWindows()
